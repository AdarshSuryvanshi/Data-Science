# %% [markdown]
# ## EDA And Feature Engineering Of Google Play Store Dataset
#
# 1) Problem statement.
# Today, 1.85 million different apps are available for users to download. Android users have even more from which to choose, with 2.56 million available through the Google Play Store. These apps have come to play a huge role in the way we live our lives today. Our Objective is to find the Most Popular Category, find the App with largest number of installs , the App with largest size etc.
# 2) Data Collection.
#
# The data consists of 20 column and 10841 rows.

# %% [markdown]
# ### Steps We Are Going to Follow
# 1. Data Clearning
# 2. Exploratory Data Analysis
# 3. Featur eEngineering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df.head()
# EVERY TIME ITS NOT COMPULSORY TO DOWNLOAD THE ENTIRE DATASET.. YOU JUST SEND THE URL LINK FOR THE DATASET.. JUST SEND THE LINK /PASS THE LINK NO NEED TO DOWNLOAD THE WHOLE CSV FILE .. OK
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.info()
# Here if you can see Almost All the Columns are having Dtype:- Object (Strings) that means they all are of "Categorical Data "... Let's try to Convert them into "Numeric Data" so that it is good for our 
# ML Model to Analyasis and Predict the Data..
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
##summary of the dataset
df.describe()
# Here's You can See 5 Number Summary ... 1) Min 2) Max 3) mean 4) Q1=25 5) Q3=75 6) IQR=(75-25)% = 50%
# In Describe.. isme joh columns hote hai Describe mai... woh sare "Numeric Data " kai Columns hote hai .. that means
# " Jo aapka dataset hai, usme jitne "(Numeric Column)" honge Utne hi  Coulmns sirf "Describe mai dikhenge"
# eg..In this "Rating " is the Only Numeric Column So, That can be showing in "Describe"..others are not okay... Just Keep this thing in our Mind...
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
##Missing Values
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ## Insights and observation
# The dataset has msising values

# %%
df.head(2)
## What we have Observed From this is "Dataset"...that This  " Dataset has Some Missing - Values "...
# Probably Those Column Have Missing Values We can .. Fix that Problems of "Missing Values".. By (Mean ,Median , Mode )..This Is Home-work for you...
# Do this and Replace this Missing Values with the Corrected one
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %% [markdown]
# ## Data Cleaning

# %%
## FROM HERE WE ARE GOING TO START "DATA-CLEANING" IN DATA-CLEANNING WE REMOVED THE UNWANTED DATA AND STORED THE WANTED DATA...

# %%
# Let'us work on this Reviws Column .. of this Dataset

# %%
df['Reviews'].unique() # Here we are checking How Many No.of People have Given Reviws to any Particular Application .... As we all know from "df.info()"..that This Reviews Column is having Dtype:-"Object"...it means that "Strings"..that means this is a "Categorical Data "
# Yes they are in Number-Format but they are In Number format Inside String Like this :- for eg :- "159","967","87510","603"..Like this
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'],
#       shape=(6002,), dtype=object)

# %%
df['Reviews'].astype(int)
## So Now If I could try to Convert that All Strings into Integers ..Like this :-
# i)  "159" - 159 
# ii) "87510" - 87510
# iii) "603" - 603.... If I try to do this ...

""" 
it is Giving me an Error and Error is that :- There is Somewhere in "Reviews" Column , There is a "Non-Numeric/Categorical Value "...it means that 
" String kai Andar FNon-Numeric/Categorical Value hai"....and woh value hai "3.0M'"
....That's why it is not Possible to Convert All Strings into Integer.... 
"""
# IF YOU WANT TO CONVERT THEN REMOVE THAT Non-Numeric/Categorical Value AND CONVERT ALL STRINGS---> INTEGERS
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df['Reviews'].astype(int)
#       2 ## So Now If I could try to Convert that All Strings into Integers ..Like this :-
#       3 # i)  "159" - 159
#       4 # ii) "87510" - 87510
#       5 # iii) "603" - 603.... If I try to do this ...
#       7 """
#       8 it is Giving me an Error and Error is that :- There is Somewhere in "Reviews" Column , There is a "Non-Numeric/Categorical Value "...it means that
#       9 " String kai Andar FNon-Numeric/Categorical Value hai"....and woh value hai "3.0M'"
#      10 ....That's why it is not Possible to Convert All Strings into Integer....
#      11 """
#
# File d:\PYTHONCODE\venv\lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
# ...

# %%
df['Reviews'].str.isnumeric().sum() # To check There are how Many Numeric Values in this "Reviwes" Column to check ...
# Numeric Values for eg :-  "159","967","87510","603" 

## as you could see in answer There are Total 10840 Numeric values , but in (df.shape) there are total 108401 rows...that means kisi ek Row pai Numeric Value Nahi hai
# Non-Numeric/Categorical Value Hai...
# To check Ki Konse Row Pai Konsi Non-Numeric/Categorical Value Hai.... we can do
# Out:
# np.int64(10840)

# %%
df[~df['Reviews'].str.isnumeric()] # I have use (~) this not symbol.. by this jaha pai Numeric Value Nahi hai .. woh Row and Non-Numeric/Categorical Value
# print honge Numeric print Nahi Honge...
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
## As you Can see "3.0M" This is Non-Numeric/Categorical Value Which is Present in the Reviwes columns .... You can remove it and then Convert All your "Strings" into "Integers"
# So then , The Reviwes Column is Convert to "Non-Numeric/Categorical Value" to"Numeric Value" (Integer)...

# %% [markdown]
# WHATEVER CHANGES AND DATA-CLEANING I WILL DO INSDE (df_copy)..ORIGINAL I'LL STAY AS IT IS.. AND CHANGES WILL DO INSIDE COPY

# %%
df_copy=df.copy() # Here I have copy df in df_copy
# WHATEVER CHANGES AND DATA-CLEANING IS THERE ... I WILL DO INSDE (df_copy)..AND ORIGINAL I'LL STAY AS IT IS.. AND CHANGES WILL DO INSIDE COPY

# %%
df_copy=df_copy.drop(df_copy.index[10472]) ### Here in this Copied Dataframe.. name:-"df_copy".. I am Going to Drop that Row that Contains 
# "Non-Numeric/Categorical Value".."3.0M"

# %%
df_copy[~df_copy['Reviews'].str.isnumeric()]  #Here  I have use (~) this not symbol.. by this jaha pai Numeric Value Nahi hai .. woh Row and Non-Numeric/Categorical Value
# print honge Numeric print Nahi Honge...

## As you could see Below We have Succesfully Deleted All "Non-Numeric/Categorical Value" from the Reviwes Columns
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
## Convert Review Datatype to int
df_copy['Reviews']=df_copy['Reviews'].astype(int) ### Now you Can easily Convert All the Strings into Integers

# %%
df_copy.info()
# see 3rd columns[Reviwes]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.2+ MB

# %% [markdown]
# ### df['Reviews'].astype(int)
# This Step is Important in Data-Cleaning Called "TypeCasting".. Where you understands Actully Where data is Not get Satisfies... That part need to be Clean... Doing Type-Casting is Important

# %%
## Next we can see "Size"
df_copy['Size'].unique() # Here you can See All the Unique Size of all Applications 
## Now you can see Here  All the Size are in the form of either "Millions(M) , Thousands (K) or Any other value ..." There is no any fixed Size over here
## If I want to Give This Dataset to ML-Model this dataset Needs To be Cleaned ...and try to Place All Values in Single Unit... But, Here Few are in "Miilins(M)" and Few in "K(Thousands)".... we need to Convert All of them Into Single Unit
# To convert to Single Unit.. You All know that 
# 1M == 1000 K----(1K =1000)..
# Here We willl try to Stored All the Values in (K)..So To Stored All the Values in (K).. All Millions(M) Need to Convert to (K)..
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
# 19000K==19M
# 89k ==89000
# 658M ==658000K
# 552K==552000

# %%
df_copy['Size'].isnull().sum() # There is no Any Missing Values in this "Column"
# Out:
# np.int64(0)

# %%
# HERE WE ARE CONVERTING ALL THE SIZE INTO "K"..
df_copy['Size']=df_copy['Size'].str.replace('M','000') # jaha pai bhi (M) hoga replace with 000
df_copy['Size']=df_copy['Size'].str.replace('k','') # jaha pai bhi (K) hoga replace with 
df_copy['Size']=df_copy['Size'].replace('Varies with device',np.nan) # jaha pai bhi (Varies with device) hoga replace with Nan

# At the End Convert Whole "Size" Column into (Float)
df_copy['Size']=df_copy['Size'].astype(float)

# %%
df_copy['Size']
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10839        NaN
# 10840    19000.0
# Name: Size, Length: 10840, dtype: float64

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.2+ MB

# %%
## Now we will Do for "Installers" :- It will tell The , Total Installers across the Globe.. for that Applications 

df_copy['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df_copy['Price'].unique() # All the Uniques values for that Application
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
chars_to_remove_from_columns=['+',',','$'] # We are trying to Remove this Characters from Column "Price" and "Installs"
coloumns_to_clean=['Installs','Price']
for item in chars_to_remove_from_columns:
    for cols in coloumns_to_clean:
        df_copy[cols]=df_copy[cols].str.replace(item,'') # Here I am Removing Every Special  Charater from My Both Columns and Replacing Them with a 
        # Blank space ....

# %%
df_copy['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df_copy['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df_copy['Installs']=df_copy['Installs'].astype('int')
df_copy['Price']=df_copy['Price'].astype('float')

# %%
## AFTER REMOVING ALL SPECIAL CHARACTERS WITH BLANK SPACE ... WE SUCCESFULLY CONVERT ALL STRINGS INTO (FLOATS AND INTEGERS)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
## Handlling Last update feature
df_copy['Last Updated'].unique() # Here In this We have Some Dates In the for of ("Categorical Data").. We will try to Convert this Dates into 
# Numeric Data ..
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       shape=(1377,), dtype=object)

# %%
df_copy['Last Updated']=pd.to_datetime(df_copy['Last Updated'])
# Here I have Converted My "Last_UPdated this Coulmn into Date-time"..

# Here I have separately Creates 3 New  Columns , By which I am Separating (Date , Month and a Year) .. This all New Columns Will be Automatically Converted In the form of "Integer"
df_copy['Day']=df_copy['Last Updated'].dt.day
df_copy['Month']=df_copy['Last Updated'].dt.month
df_copy['Year']=df_copy['Last Updated'].dt.year

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  datetime64[ns]
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Day             10840 non-null  int32
#  14  Month           10840 non-null  int32
#  15  Year            10840 non-null  int32
# ...

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
df_copy.to_csv('data/google_cleaned.csv') # Stored and Save This New and Updated Data-cleaned File in the New Data folder 
# df is our original file...and All Data cleaning we did in this "Copied filed"..i.e  df_copy..

## Now Google- Play- Stores Data-Cleaned File is get saved in the Folder:- Data

# %% [markdown]
# ### TILL HERE WE STUDY ALL ABOUT DATA- CLEANING NOW WE WILL LEARN EDA

# %% [markdown]
# ## EDA

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...

# %%
df_copy[df_copy.duplicated('App')].shape
# Basically There are 10,000 records and out of 10,000 if you see Below 1181 Records are Duplicates...
# Out:
# (1181, 16)

# %% [markdown]
# ## Observation
# The dataset has duplicate records

# %%
df_copy=df_copy.drop_duplicates(subset=['App'],keep='first') # Now We are Going Reduct All that 1181 records from That 10000 records ... So that Our Data- will be Cleaned 
# And reaming (10000-1181) will you can saw over here..
# 
# keep='first' :- By using this Only 1st Record will be "Stay" there and Duplicates will be Removed  
## Or Otherwise.. you can use (inplace=True).. instead of keep='first'...

# %%
df_copy.shape
# Few we Cleaned During Data-Cleaning and few we Reduct Here.. Now only this Much are Remaing..
# Out:
# (9659, 16)

# %% [markdown]
# ## Explore Data

# %%
numeric_features = [feature for feature in df_copy.columns if df_copy[feature].dtype != 'O'] # Numerical Data is Not Equal to Strings.. So it will not Satisfied This..
categorical_features = [feature for feature in df_copy.columns if df_copy[feature].dtype == 'O'] # Categorical  Data is  Equal to Strings.. So it will  Satisfied This..

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 9 numerical features : ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Last Updated', 'Day', 'Month', 'Year']
#
# We have 7 categorical features : ['App', 'Category', 'Type', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver']

# %% [markdown]
# ## 3.2 Feature Information
# 1. App :- Name of the App
# 2. Category :- Category under which the App falls.
# 3. Rating :- Application's rating on playstore
# 4. Reviews :- Number of reviews of the App.
# 5. Size :- Size of the App.
# 6. Install :- Number of Installs of the App
# 7. Type :- If the App is free/paid
# 8. Price :- Price of the app (0 if it is Free)
# 9. Content Rating :- Appropiate Target Audience of the App.
# 10. Genres:- Genre under which the App falls.
# 11. Last Updated :- Date when the App was last updated
# 12. Current Ver :- Current Version of the Application
# 13. Android Ver :- Minimum Android Version required to run the App

# %%
## Proportion of count data on categorical columns
for col in categorical_features:
    print(df[col].value_counts(normalize=True)*100)  # (normalize=True) is used to Give Value_counts in terms of Percentage...Here We  have Multiplied with 100.. 
    print('---------------------------')            # Value_counts :- Is used to give Total Counts of that Column.
# Out:
# App
# ROBLOX                                               0.083018
# CBS Sports App - Scores, News, Stats & Watch Live    0.073794
# Duolingo: Learn Languages Free                       0.064570
# Candy Crush Saga                                     0.064570
# 8 Ball Pool                                          0.064570
#                                                        ...
# Fr. Daoud Lamei                                      0.009224
# Poop FR                                              0.009224
# PLMGSS FR                                            0.009224
# List iptv FR                                         0.009224
# Kids Paint Free - Drawing Fun                        0.009224
# Name: proportion, Length: 9660, dtype: float64
# ---------------------------
# Category
# FAMILY                 18.190204
# GAME                   10.552532
# TOOLS                   7.776035
# MEDICAL                 4.270824
# BUSINESS                4.243151
# ...

# %%
## Proportion of count data on numerical columns
# To print the Graph for "All Numeric Columns "
plt.figure(figsize=(15, 15)) # Whole Size of Figure
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)): # Go till Length of Numeric Features 
    plt.subplot(5, 3, i+1) # Here Limit of 5 rows and 3 columns and Increaemnt by 1 after every iteration 
    sns.kdeplot(x=df_copy[numeric_features[i]],shade=True, color='r') # kde-plot:- Means Only Plot the KDE curve
    plt.xlabel(numeric_features[i]) ## All Numeric Features one-by-one on X- Axis
    plt.tight_layout() # To Make Graphs proper and Vizualizeanle

# %% [markdown]
# ## Observations
# - Rating and Year is left skewed while Reviews,Size,Installs and Price are right skewed

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2") ## Always Whenever for Categorical Data.. Always Categorical (Data/ Columns/ Values) are Visualize by "Counter-Plot"  
    plt.xlabel(category[i])
    plt.xticks(rotation=45) # Becoz of this All Labels on X-axis is get  Tilt by 45 Degree
    plt.tight_layout() # Lay-out is Tight for proper Vizualzation

# %% [markdown]
# ## Which is the most popular app category?

# %%
df_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver   Android Ver  Day  \
# 0               Art & Design   2018-01-07       1.0.0  4.0.3 and up    7
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0  4.0.3 and up   15
#
#    Month  Year
# 0      1  2018
# 1      1  2018

# %%
df_copy['Category'].value_counts().plot.pie(y=df_copy['Category'],figsize=(15,16),autopct='%1.1f')
# Value_counts will Provide Total no of Count... , Here we are Plotting "Pie Chart"..,Fixed Figsize , autopct to show Percentage... 
# Here we Can Also Add Shadow.. Also Can Remove Any Particular slice..
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Observations
#
# 1. There are more kinds of apps in playstore which are under category of family, games & tools
# 2. Beatuty,comics,arts and weather kinds of apps are very less in playstore

# %%
## Top 10 App Categories
category = pd.DataFrame(df_copy['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'count'},inplace=True)

# %%
category
# Out:
#                      count
# Category
# FAMILY                1832
# GAME                   959
# TOOLS                  827
# BUSINESS               420
# MEDICAL                395
# PERSONALIZATION        376
# PRODUCTIVITY           374
# LIFESTYLE              369
# FINANCE                345
# SPORTS                 325
# COMMUNICATION          315
# HEALTH_AND_FITNESS     288
# PHOTOGRAPHY            281
# NEWS_AND_MAGAZINES     254
# SOCIAL                 239
# BOOKS_AND_REFERENCE    222
# TRAVEL_AND_LOCAL       219
# SHOPPING               202
# DATING                 171
# VIDEO_PLAYERS          163
# MAPS_AND_NAVIGATION    131
# EDUCATION              119
# FOOD_AND_DRINK         112
# ENTERTAINMENT          102
# AUTO_AND_VEHICLES       85
# LIBRARIES_AND_DEMO      84
# WEATHER                 79
# HOUSE_AND_HOME          74
# ART_AND_DESIGN          64
# EVENTS                  64
# PARENTING               60
# COMICS                  56
# BEAUTY                  53

# %%
## top 10 app
plt.figure(figsize=(15,6))
sns.barplot(x=category.index[:10], y ='count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Insights
# 1. Family category has the most number of apps with 18% of apps belonging to it, followed by Games category which has 11% of the apps.
# 2. Least number of apps belong to the Beauty category with less than 1% of the total apps belonging to it.

# %% [markdown]
# ## Internal Assignments
# 1. Which Category has largest number of installations??
# 2. What are the Top 5 most installed Apps in Each popular Categories ??
# 3. How many apps are there on Google Play Store which get 5 ratings??

# %% [markdown]
# ## Which Category has largest number of installations??

# %%
df_cat_installs = df_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index() # Easy Just have use Groupby and did some sum sort VAlues accordingly
df_cat_installs.Installs = df_cat_installs.Installs/1000000000# converting into billions
df2 = df_cat_installs.head(10)
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 ,palette="Set2")
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %% [markdown]
# ## Insights
# 1. Out of all the categories "GAME" has the most number of Installations.
# 2. With almost 35 Billion Installations GAME is the most popular Category in Google App store

# %% [markdown]
# ## What are the Top 5 most installed Apps in Each popular Categories ??

# %%
dfa = df_copy.groupby(['Category' ,'App'])['Installs'].sum().reset_index() # Sum installs cha honar 
dfa = dfa.sort_values('Installs', ascending = False)
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App',palette="Set1" )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %% [markdown]
# ## Insights
# - Most popular game is Subway Surfers.
# - Most popular communication app is Hangouts.
# - Most popular productivity app is Google Drive.
# - Most popular social app is Instagram.

# %% [markdown]
# ## How many apps are there on Google Play Store which get 5 ratings??

# %%
rating = df_copy.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()

toprating_apps = rating[rating.Rating == 5.0]
print("Number of 5 rated apps",toprating_apps.shape[0])
toprating_apps.head(1)
# Out:
# Number of 5 rated apps 271
#   Category  Installs          App  Rating
# 0   FAMILY        10  DN Employee     5.0

# %% [markdown]
# ## Result
# - There are 271 five rated apps on Google Play store
# - Top most is 'CT Brain Interpretation' from 'Family' Category

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# ...
