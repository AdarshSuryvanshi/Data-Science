# %% [markdown]
# ## SMOTE(Synthetic Minority Oversampling Technique)
# SMOTE (Synthetic Minority Over-sampling Technique) is a technique used in machine learning to address imbalanced datasets where the minority class has significantly fewer instances than the majority class. SMOTE involves generating synthetic instances of the minority class by interpolating between existing instances.

# %%
from sklearn.datasets import make_classification
# Here We are Importing this Datasets becoz to  Create a Im-Balance Dataset

# %%
X,y=make_classification(n_samples=1000,n_redundant=0,n_features=2,n_clusters_per_class=1,
                   weights=[0.90],random_state=12)
# Total Sample Points :- 1000 ,
# features =2... there are 2 Features , # clusters means Gropus in class

# %%
import pandas as pd
df1=pd.DataFrame(X,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
# Creating 2 Data-frames .. for 2 Classes 
final_df=pd.concat([df1,df2],axis=1) # Mergeing 2 Data-Frames and Make single data-Frame 
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts() # Value- Counts is used to Count the Total Data-Points In each Column
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])
# Here Purple/Violet is = Majority and Yellow= Minority ........ This is just to Visualize you the Data

# %%
# !pip install imblearn

# As in Previous Techniques we used (resample) this Library to Create and Increses The Data-Points for Up-sampling ... Like that only 
 # To Increaes the Data-points in this SMOTE Techniques,,, we are going to used Librarry Called (imblearn).. This is used to increases the Data-points..as equal to Majority

# %%
from imblearn.over_sampling import SMOTE
# Whatever the Concept we have learn about SMOTE, that all will do by this librarry , This Librarry is responsible to Do all those Things That we have discuess in Concet

# %%
## transform the dataset
oversample=SMOTE()
X,y=oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(y[y==0])
# Out:
# 900

# %%
len(y[y==1])
# Now Here Both the Parts are Become eaqual
# Out:
# 900

# %%
df1=pd.DataFrame(X,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
oversample_df=pd.concat([df1,df2],axis=1)
# Here I am Con-Catting Both the Parts , Merging together , so that Make a Single Datafra,e

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['target'])

# Now Here In this Diagram You Can see Minority data-points Are increases as till the Equalize the Majority ..Here Data-points are incraeses  .....  as well as Expansion of Data Also Happened Both the 
# Condtion Satisfied over Here  ..... Data-points are Connected by "Interploating Connection "
