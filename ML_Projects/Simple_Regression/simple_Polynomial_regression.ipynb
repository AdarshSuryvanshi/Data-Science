# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Weight-Height Polynomial Dataset.csv")

# %%
df.head()
# Out:
#        Weight      Height
# 0   69.963210   96.644532
# 1  116.057145  196.156340
# 2   98.559515  145.862047
# 3   87.892679  121.157923
# 4   52.481491   68.971292

# %%
plt.hist(x=df["Height"],bins=10,edgecolor="black",color="orange")
# Out:
# (array([15.,  9.,  3.,  7.,  5.,  2.,  0.,  3.,  3.,  3.]),
#  array([ 68.97129164,  82.3405049 ,  95.70971816, 109.07893141,
#         122.44814467, 135.81735793, 149.18657119, 162.55578444,
#         175.9249977 , 189.29421096, 202.66342422]),
#  <BarContainer object of 10 artists>)

# %%
## Scatter Plot :- To See the Relationship between "Independent Feature" and "Dependent Feature"
plt.scatter(df["Weight"],df["Height"])
plt.xlabel("Weight")
plt.ylabel("Height")
# Out:
# Text(0, 0.5, 'Height')
